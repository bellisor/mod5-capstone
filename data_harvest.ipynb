# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time

# third-party imports
import numpy as np
import pandas as pd
import requests

# customisations - ensure tables show all columns
pd.set_option("max_columns", 100)

from config import api_key

# %% [markdown]
# First step is to get a list of all relevant appids on steam using steam spy.
#
# We begin by testing connection to api

# %%
url = "https://steamspy.com/api.php"

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get(url)
# Print the status code of the response.
print(response.status_code)

# %%
def get_request(url, parameters=None):
    """Return json-formatted response of a get request using optional parameters.
    
    Parameters
    ----------
    url : string
    parameters : {'parameter': 'value'}
        parameters to pass as part of get request
    
    Returns
    -------
    json_data
        json-formatted response (dict-like)
    """
    try:
        response = requests.get(url=url, params=parameters)
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(5, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        
        # recusively try again
        return get_request(url, parameters)
    
    if response:
        return response.json()
    else:
        # response is none usually means too many requests. Wait and try again 
        print('No response, waiting 30 seconds...')
        time.sleep(30)
        print('Retrying.')
        return get_request(url, parameters)

# %%
url = "https://steamspy.com/api.php"
parameters = {"request": "all"}

# request 'all' from steam spy and parse into dataframe
json_data = get_request(url, parameters=parameters)
steam_spy_all = pd.DataFrame.from_dict(json_data, orient='index')

# generate sorted app_list from steamspy data
app_list = steam_spy_all[['appid', 'name']].sort_values('appid').reset_index(drop=True)

# %%
# export disabled to keep consistency across download sessions
app_list.to_csv('../data/download/app_list_SS.csv', index=False)

# %%
app_list.info
# Out:
# <bound method DataFrame.info of          appid                          name
# 0           10                Counter-Strike
# 1           20         Team Fortress Classic
# 2           30                 Day of Defeat
# 3           40            Deathmatch Classic
# 4           50     Half-Life: Opposing Force
# ...        ...                           ...
# 37679  1376260  HTML5 Javascript Game Engine
# 37680  1376940                Monster Killer
# 37681  1378290                   The Citadel
# 37682  1380110    Sprite Basic 2 Game Engine
# 37683  1384770                   Scrutinized
#
# [37684 rows x 2 columns]>

# %%
# instead read from stored csv
app_list = pd.read_csv('../data/download/app_list_SS.csv')

# display first few rows
app_list.head()
# Out:
#    appid                       name
# 0     10             Counter-Strike
# 1     20      Team Fortress Classic
# 2     30              Day of Defeat
# 3     40         Deathmatch Classic
# 4     50  Half-Life: Opposing Force

# %%
def get_app_data(start, stop, parser, pause):
    """Return list of app data generated from parser.
    
    parser : function to handle request
    """
    app_data = []
    
    # iterate through each row of app_list, confined by start and stop
    for index, row in app_list[start:stop].iterrows():
        print('Current index: {}'.format(index), end='\r')
        
        appid = row['appid']
        name = row['name']

        # retrive app data for a row, handled by supplied parser, and append to list
        data = parser(appid, name)
        app_data.append(data)

        time.sleep(pause) # prevent overloading api with requests
    
    return app_data

def process_batches(parser, app_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=100, pause=1):
    """Process app data in batches, writing directly to file.
    
    parser : custom function to format request
    app_list : dataframe of appid and name
    download_path : path to store data
    data_filename : filename to save app data
    index_filename : filename to store highest index written
    columns : column names for file
    
    Keyword arguments:
    
    begin : starting index (get from index_filename, default 0)
    end : index to finish (defaults to end of app_list)
    batchsize : number of apps to write in each batch (default 100)
    pause : time to wait after each api request (defualt 1)
    
    returns: none
    """
    print('Starting at index {}:\n'.format(begin))
    
    # by default, process all apps in app_list
    if end == -1:
        end = len(app_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    apps_written = 0
    batch_times = []
    
    for i in range(len(batches) - 1):
            start_time = time.time()

            start = batches[i]
            stop = batches[i+1]

            app_data = get_app_data(start, stop, parser, pause)

            rel_path = os.path.join(download_path, data_filename)

            # writing app data to file
            with open(rel_path, 'a', newline='', encoding='utf-8') as f:
                writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')

                for j in range(3,0,-1):
                    print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                    time.sleep(0.5)

                writer.writerows(app_data)
                print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')

            apps_written += len(app_data)

            idx_path = os.path.join(download_path, index_filename)

            # writing last index to file
            with open(idx_path, 'w') as f:
                index = stop
                print(index, file=f)

            # logging time taken
            end_time = time.time()
            time_taken = end_time - start_time

            batch_times.append(time_taken)
            mean_time = statistics.mean(batch_times)

            est_remaining = (len(batches) - i - 2) * mean_time

            remaining_td = dt.timedelta(seconds=round(est_remaining))
            time_td = dt.timedelta(seconds=round(time_taken))
            mean_td = dt.timedelta(seconds=round(mean_time))

            print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))

    print('\nProcessing batches complete. {} apps written'.format(apps_written))

# %%
def reset_index(download_path, index_filename):
    """Reset index in file to 0."""
    rel_path = os.path.join(download_path, index_filename)
    
    with open(rel_path, 'w') as f:
        print(0, file=f)
        

def get_index(download_path, index_filename):
    """Retrieve index from file, returning 0 if file not found."""
    try:
        rel_path = os.path.join(download_path, index_filename)

        with open(rel_path, 'r') as f:
            index = int(f.readline())
    
    except FileNotFoundError:
        index = 0
        
    return index


def prepare_data_file(download_path, filename, index, columns):
    """Create file and write headers if index is 0."""
    if index == 0:
        rel_path = os.path.join(download_path, filename)

        with open(rel_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

# %%
def parse_steam_request(appid, name):
    """Unique parser to handle data from Steam Store API.
    
    Returns : json formatted data (dict-like)
    """
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids": appid}
    
    json_data = get_request(url, parameters=parameters)
    json_app_data = json_data[str(appid)]
    
    if json_app_data['success']:
        data = json_app_data['data']
    else:
        data = {'name': name, 'steam_appid': appid}
        
    return data


# Set file parameters
download_path = '../data/download'
steam_app_data = 'steam_app_data.csv'
steam_index = 'steam_index.txt'

steam_columns = [
    'type', 'name', 'steam_appid', 'required_age', 'is_free', 'controller_support',
    'dlc', 'detailed_description', 'about_the_game', 'short_description', 'fullgame',
    'supported_languages', 'header_image', 'website', 'pc_requirements', 'mac_requirements',
    'linux_requirements', 'legal_notice', 'drm_notice', 'ext_user_account_notice',
    'developers', 'publishers', 'demos', 'price_overview', 'packages', 'package_groups',
    'platforms', 'metacritic', 'reviews', 'categories', 'genres', 'screenshots',
    'movies', 'recommendations', 'achievements', 'release_date', 'support_info',
    'background', 'content_descriptors'
]

# Overwrites last index for demonstration (would usually store highest index so can continue across sessions)
reset_index(download_path, steam_index)

# Retrieve last index downloaded from file
index = get_index(download_path, steam_index)

# Wipe or create data file and write headers if index is 0
prepare_data_file(download_path, steam_app_data, index, steam_columns)
# Out:
# Starting at index 9700:
#
# Exported lines 9700-9799 to steam_app_data.csv. Batch 0 time: 0:02:17 (avg: 0:02:17, remaining: 10:36:30)
# Exported lines 9800-9899 to steam_app_data.csv. Batch 1 time: 0:02:19 (avg: 0:02:18, remaining: 10:38:00)
# Exported lines 9900-9999 to steam_app_data.csv. Batch 2 time: 0:02:16 (avg: 0:02:17, remaining: 10:33:36)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 10000-10099 to steam_app_data.csv. Batch 3 time: 0:02:47 (avg: 0:02:25, remaining: 11:05:06)
# Exported lines 10100-10199 to steam_app_data.csv. Batch 4 time: 0:02:16 (avg: 0:02:23, remaining: 10:55:03)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 10200-10299 to steam_app_data.csv. Batch 5 time: 0:02:47 (avg: 0:02:27, remaining: 11:11:10)
# Exported lines 10300-10399 to steam_app_data.csv. Batch 6 time: 0:02:17 (avg: 0:02:26, remaining: 11:02:22)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 10400-10499 to steam_app_data.csv. Batch 7 time: 0:02:46 (avg: 0:02:28, remaining: 11:11:23)
# Exported lines 10500-10599 to steam_app_data.csv. Batch 8 time: 0:02:16 (avg: 0:02:27, remaining: 11:02:38)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 10600-10699 to steam_app_data.csv. Batch 9 time: 0:02:45 (avg: 0:02:29, remaining: 11:08:31)
# Exported lines 10700-10799 to steam_app_data.csv. Batch 10 time: 0:02:15 (avg: 0:02:27, remaining: 11:00:28)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 10800-10899 to steam_app_data.csv. Batch 11 time: 0:02:47 (avg: 0:02:29, remaining: 11:05:21)
# Exported lines 10900-10999 to steam_app_data.csv. Batch 12 time: 0:02:17 (avg: 0:02:28, remaining: 10:58:49)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 11000-11099 to steam_app_data.csv. Batch 13 time: 0:02:49 (avg: 0:02:30, remaining: 11:02:59)
# Exported lines 11100-11199 to steam_app_data.csv. Batch 14 time: 0:02:18 (avg: 0:02:29, remaining: 10:57:00)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 11200-11299 to steam_app_data.csv. Batch 15 time: 0:02:47 (avg: 0:02:30, remaining: 10:59:36)
# Exported lines 11300-11399 to steam_app_data.csv. Batch 16 time: 0:02:17 (avg: 0:02:29, remaining: 10:53:42)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 11400-11499 to steam_app_data.csv. Batch 17 time: 0:02:47 (avg: 0:02:30, remaining: 10:55:31)
# Exported lines 11500-11599 to steam_app_data.csv. Batch 18 time: 0:02:17 (avg: 0:02:29, remaining: 10:50:07)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 11600-11699 to steam_app_data.csv. Batch 19 time: 0:02:47 (avg: 0:02:30, remaining: 10:51:28)
# Exported lines 11700-11799 to steam_app_data.csv. Batch 20 time: 0:02:17 (avg: 0:02:30, remaining: 10:46:11)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 11800-11899 to steam_app_data.csv. Batch 21 time: 0:02:48 (avg: 0:02:31, remaining: 10:47:12)
# Exported lines 11900-11999 to steam_app_data.csv. Batch 22 time: 0:02:17 (avg: 0:02:30, remaining: 10:42:06)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 12000-12099 to steam_app_data.csv. Batch 23 time: 0:02:47 (avg: 0:02:31, remaining: 10:42:39)
# Exported lines 12100-12199 to steam_app_data.csv. Batch 24 time: 0:02:17 (avg: 0:02:30, remaining: 10:37:48)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 12200-12299 to steam_app_data.csv. Batch 25 time: 0:02:48 (avg: 0:02:31, remaining: 10:38:18)
# Exported lines 12300-12399 to steam_app_data.csv. Batch 26 time: 0:02:16 (avg: 0:02:30, remaining: 10:33:32)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 12400-12499 to steam_app_data.csv. Batch 27 time: 0:02:47 (avg: 0:02:31, remaining: 10:33:36)
# Exported lines 12500-12599 to steam_app_data.csv. Batch 28 time: 0:02:17 (avg: 0:02:30, remaining: 10:29:02)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 12600-12699 to steam_app_data.csv. Batch 29 time: 0:02:48 (avg: 0:02:31, remaining: 10:28:59)
# Exported lines 12700-12799 to steam_app_data.csv. Batch 30 time: 0:02:18 (avg: 0:02:31, remaining: 10:24:43)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 12800-12899 to steam_app_data.csv. Batch 31 time: 0:02:49 (avg: 0:02:31, remaining: 10:24:34)
# Exported lines 12900-12999 to steam_app_data.csv. Batch 32 time: 0:02:17 (avg: 0:02:31, remaining: 10:20:15)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 13000-13099 to steam_app_data.csv. Batch 33 time: 0:02:48 (avg: 0:02:31, remaining: 10:19:53)
# Exported lines 13100-13199 to steam_app_data.csv. Batch 34 time: 0:02:15 (avg: 0:02:31, remaining: 10:15:30)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 13200-13299 to steam_app_data.csv. Batch 35 time: 0:02:46 (avg: 0:02:31, remaining: 10:14:43)
# Exported lines 13300-13399 to steam_app_data.csv. Batch 36 time: 0:02:17 (avg: 0:02:31, remaining: 10:10:41)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 13400-13499 to steam_app_data.csv. Batch 37 time: 0:02:48 (avg: 0:02:31, remaining: 10:09:59)
# Exported lines 13500-13599 to steam_app_data.csv. Batch 38 time: 0:02:17 (avg: 0:02:31, remaining: 10:06:00)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 13600-13699 to steam_app_data.csv. Batch 39 time: 0:02:48 (avg: 0:02:31, remaining: 10:05:10)
# Exported lines 13700-13799 to steam_app_data.csv. Batch 40 time: 0:02:18 (avg: 0:02:31, remaining: 10:01:19)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 13800-13899 to steam_app_data.csv. Batch 41 time: 0:02:48 (avg: 0:02:31, remaining: 10:00:24)
# Exported lines 13900-13999 to steam_app_data.csv. Batch 42 time: 0:02:16 (avg: 0:02:31, remaining: 9:56:26)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 14000-14099 to steam_app_data.csv. Batch 43 time: 0:02:46 (avg: 0:02:31, remaining: 9:55:15)
# Exported lines 14100-14199 to steam_app_data.csv. Batch 44 time: 0:02:17 (avg: 0:02:31, remaining: 9:51:26)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 14200-14299 to steam_app_data.csv. Batch 45 time: 0:02:46 (avg: 0:02:31, remaining: 9:50:09)
# Exported lines 14300-14399 to steam_app_data.csv. Batch 46 time: 0:02:16 (avg: 0:02:31, remaining: 9:46:24)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 14400-14499 to steam_app_data.csv. Batch 47 time: 0:02:47 (avg: 0:02:31, remaining: 9:45:12)
# Exported lines 14500-14599 to steam_app_data.csv. Batch 48 time: 0:02:19 (avg: 0:02:31, remaining: 9:41:41)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 14600-14699 to steam_app_data.csv. Batch 49 time: 0:02:48 (avg: 0:02:31, remaining: 9:40:27)
# Exported lines 14700-14799 to steam_app_data.csv. Batch 50 time: 0:02:17 (avg: 0:02:31, remaining: 9:36:51)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 14800-14899 to steam_app_data.csv. Batch 51 time: 0:02:49 (avg: 0:02:31, remaining: 9:35:36)
# Exported lines 14900-14999 to steam_app_data.csv. Batch 52 time: 0:02:17 (avg: 0:02:31, remaining: 9:32:03)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 15000-15099 to steam_app_data.csv. Batch 53 time: 0:02:47 (avg: 0:02:32, remaining: 9:30:40)
# Exported lines 15100-15199 to steam_app_data.csv. Batch 54 time: 0:02:19 (avg: 0:02:31, remaining: 9:27:15)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 15200-15299 to steam_app_data.csv. Batch 55 time: 0:02:48 (avg: 0:02:32, remaining: 9:25:52)
# Exported lines 15300-15399 to steam_app_data.csv. Batch 56 time: 0:02:19 (avg: 0:02:31, remaining: 9:22:31)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 15400-15499 to steam_app_data.csv. Batch 57 time: 0:02:46 (avg: 0:02:32, remaining: 9:20:58)
# Exported lines 15500-15599 to steam_app_data.csv. Batch 58 time: 0:02:17 (avg: 0:02:31, remaining: 9:17:31)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 15600-15699 to steam_app_data.csv. Batch 59 time: 0:02:48 (avg: 0:02:32, remaining: 9:15:59)
# Exported lines 15700-15799 to steam_app_data.csv. Batch 60 time: 0:02:17 (avg: 0:02:31, remaining: 9:12:35)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 15800-15899 to steam_app_data.csv. Batch 61 time: 0:02:46 (avg: 0:02:32, remaining: 9:10:56)
# Exported lines 15900-15999 to steam_app_data.csv. Batch 62 time: 0:02:16 (avg: 0:02:31, remaining: 9:07:32)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 16000-16099 to steam_app_data.csv. Batch 63 time: 0:02:45 (avg: 0:02:32, remaining: 9:05:48)
# Exported lines 16100-16199 to steam_app_data.csv. Batch 64 time: 0:02:17 (avg: 0:02:31, remaining: 9:02:29)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 16200-16299 to steam_app_data.csv. Batch 65 time: 0:02:50 (avg: 0:02:32, remaining: 9:00:56)
# Exported lines 16300-16399 to steam_app_data.csv. Batch 66 time: 0:02:16 (avg: 0:02:31, remaining: 8:57:36)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 16400-16499 to steam_app_data.csv. Batch 67 time: 0:02:46 (avg: 0:02:32, remaining: 8:55:51)
# Exported lines 16500-16599 to steam_app_data.csv. Batch 68 time: 0:02:17 (avg: 0:02:31, remaining: 8:52:34)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 16600-16699 to steam_app_data.csv. Batch 69 time: 0:02:45 (avg: 0:02:32, remaining: 8:50:44)
# Exported lines 16700-16799 to steam_app_data.csv. Batch 70 time: 0:02:17 (avg: 0:02:31, remaining: 8:47:29)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 16800-16899 to steam_app_data.csv. Batch 71 time: 0:02:48 (avg: 0:02:32, remaining: 8:45:45)
# Exported lines 16900-16999 to steam_app_data.csv. Batch 72 time: 0:02:18 (avg: 0:02:31, remaining: 8:42:35)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 17000-17099 to steam_app_data.csv. Batch 73 time: 0:02:47 (avg: 0:02:32, remaining: 8:40:48)
# Exported lines 17100-17199 to steam_app_data.csv. Batch 74 time: 0:02:18 (avg: 0:02:32, remaining: 8:37:38)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 17200-17299 to steam_app_data.csv. Batch 75 time: 0:02:45 (avg: 0:02:32, remaining: 8:35:43)
# Exported lines 17300-17399 to steam_app_data.csv. Batch 76 time: 0:02:16 (avg: 0:02:31, remaining: 8:32:30)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 17400-17499 to steam_app_data.csv. Batch 77 time: 0:02:47 (avg: 0:02:32, remaining: 8:30:37)
# Exported lines 17500-17599 to steam_app_data.csv. Batch 78 time: 0:02:16 (avg: 0:02:31, remaining: 8:27:27)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 17600-17699 to steam_app_data.csv. Batch 79 time: 0:02:46 (avg: 0:02:32, remaining: 8:25:31)
# Exported lines 17700-17799 to steam_app_data.csv. Batch 80 time: 0:02:16 (avg: 0:02:31, remaining: 8:22:22)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 17800-17899 to steam_app_data.csv. Batch 81 time: 0:02:47 (avg: 0:02:32, remaining: 8:20:27)
# Exported lines 17900-17999 to steam_app_data.csv. Batch 82 time: 0:02:15 (avg: 0:02:31, remaining: 8:17:16)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 18000-18099 to steam_app_data.csv. Batch 83 time: 0:02:46 (avg: 0:02:32, remaining: 8:15:18)
# Exported lines 18100-18199 to steam_app_data.csv. Batch 84 time: 0:02:20 (avg: 0:02:31, remaining: 8:12:19)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 18200-18299 to steam_app_data.csv. Batch 85 time: 0:02:47 (avg: 0:02:32, remaining: 8:10:23)
# Exported lines 18300-18399 to steam_app_data.csv. Batch 86 time: 0:02:17 (avg: 0:02:31, remaining: 8:07:18)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 18400-18499 to steam_app_data.csv. Batch 87 time: 0:02:47 (avg: 0:02:32, remaining: 8:05:20)
# Exported lines 18500-18599 to steam_app_data.csv. Batch 88 time: 0:02:17 (avg: 0:02:32, remaining: 8:02:17)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 18600-18699 to steam_app_data.csv. Batch 89 time: 0:02:46 (avg: 0:02:32, remaining: 8:00:16)
# Exported lines 18700-18799 to steam_app_data.csv. Batch 90 time: 0:02:17 (avg: 0:02:32, remaining: 7:57:15)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 18800-18899 to steam_app_data.csv. Batch 91 time: 0:02:47 (avg: 0:02:32, remaining: 7:55:14)
# Exported lines 18900-18999 to steam_app_data.csv. Batch 92 time: 0:02:17 (avg: 0:02:32, remaining: 7:52:13)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 19000-19099 to steam_app_data.csv. Batch 93 time: 0:02:48 (avg: 0:02:32, remaining: 7:50:14)
# Exported lines 19100-19199 to steam_app_data.csv. Batch 94 time: 0:02:17 (avg: 0:02:32, remaining: 7:47:14)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 19200-19299 to steam_app_data.csv. Batch 95 time: 0:02:48 (avg: 0:02:32, remaining: 7:45:14)
# Exported lines 19300-19399 to steam_app_data.csv. Batch 96 time: 0:02:18 (avg: 0:02:32, remaining: 7:42:17)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 19400-19499 to steam_app_data.csv. Batch 97 time: 0:02:48 (avg: 0:02:32, remaining: 7:40:17)
# Exported lines 19500-19599 to steam_app_data.csv. Batch 98 time: 0:02:18 (avg: 0:02:32, remaining: 7:37:20)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 19600-19699 to steam_app_data.csv. Batch 99 time: 0:02:48 (avg: 0:02:32, remaining: 7:35:18)
# Exported lines 19700-19799 to steam_app_data.csv. Batch 100 time: 0:02:18 (avg: 0:02:32, remaining: 7:32:23)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 19800-19899 to steam_app_data.csv. Batch 101 time: 0:02:47 (avg: 0:02:32, remaining: 7:30:18)
# Exported lines 19900-19999 to steam_app_data.csv. Batch 102 time: 0:02:17 (avg: 0:02:32, remaining: 7:27:20)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 20000-20099 to steam_app_data.csv. Batch 103 time: 0:02:47 (avg: 0:02:32, remaining: 7:25:14)
# Exported lines 20100-20199 to steam_app_data.csv. Batch 104 time: 0:02:16 (avg: 0:02:32, remaining: 7:22:16)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 20200-20299 to steam_app_data.csv. Batch 105 time: 0:02:47 (avg: 0:02:32, remaining: 7:20:09)
# Exported lines 20300-20399 to steam_app_data.csv. Batch 106 time: 0:02:16 (avg: 0:02:32, remaining: 7:17:12)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 20400-20499 to steam_app_data.csv. Batch 107 time: 0:02:46 (avg: 0:02:32, remaining: 7:15:04)
# Exported lines 20500-20599 to steam_app_data.csv. Batch 108 time: 0:02:16 (avg: 0:02:32, remaining: 7:12:08)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 20600-20699 to steam_app_data.csv. Batch 109 time: 0:02:47 (avg: 0:02:32, remaining: 7:09:59)
# Exported lines 20700-20799 to steam_app_data.csv. Batch 110 time: 0:02:16 (avg: 0:02:32, remaining: 7:07:04)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 20800-20899 to steam_app_data.csv. Batch 111 time: 0:02:47 (avg: 0:02:32, remaining: 7:04:55)
# Exported lines 20900-20999 to steam_app_data.csv. Batch 112 time: 0:02:17 (avg: 0:02:32, remaining: 7:02:01)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 21000-21099 to steam_app_data.csv. Batch 113 time: 0:02:46 (avg: 0:02:32, remaining: 6:59:50)
# Exported lines 21100-21199 to steam_app_data.csv. Batch 114 time: 0:02:18 (avg: 0:02:32, remaining: 6:56:59)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 21200-21299 to steam_app_data.csv. Batch 115 time: 0:02:47 (avg: 0:02:32, remaining: 6:54:48)
# Exported lines 21300-21399 to steam_app_data.csv. Batch 116 time: 0:02:16 (avg: 0:02:32, remaining: 6:51:55)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 21400-21499 to steam_app_data.csv. Batch 117 time: 0:02:46 (avg: 0:02:32, remaining: 6:49:42)
# Exported lines 21500-21599 to steam_app_data.csv. Batch 118 time: 0:02:15 (avg: 0:02:32, remaining: 6:46:48)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 21600-21699 to steam_app_data.csv. Batch 119 time: 0:02:48 (avg: 0:02:32, remaining: 6:44:38)
# Exported lines 21700-21799 to steam_app_data.csv. Batch 120 time: 0:02:15 (avg: 0:02:32, remaining: 6:41:45)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 21800-21899 to steam_app_data.csv. Batch 121 time: 0:02:46 (avg: 0:02:32, remaining: 6:39:32)
# Exported lines 21900-21999 to steam_app_data.csv. Batch 122 time: 0:02:15 (avg: 0:02:32, remaining: 6:36:39)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 22000-22099 to steam_app_data.csv. Batch 123 time: 0:02:49 (avg: 0:02:32, remaining: 6:34:29)
# Exported lines 22100-22199 to steam_app_data.csv. Batch 124 time: 0:02:17 (avg: 0:02:32, remaining: 6:31:40)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 22200-22299 to steam_app_data.csv. Batch 125 time: 0:02:48 (avg: 0:02:32, remaining: 6:29:28)
# Exported lines 22300-22399 to steam_app_data.csv. Batch 126 time: 0:02:16 (avg: 0:02:32, remaining: 6:26:37)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 22400-22499 to steam_app_data.csv. Batch 127 time: 0:02:46 (avg: 0:02:32, remaining: 6:24:23)
# Exported lines 22500-22599 to steam_app_data.csv. Batch 128 time: 0:02:17 (avg: 0:02:32, remaining: 6:21:33)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 22600-22699 to steam_app_data.csv. Batch 129 time: 0:02:47 (avg: 0:02:32, remaining: 6:19:20)
# Exported lines 22700-22799 to steam_app_data.csv. Batch 130 time: 0:02:16 (avg: 0:02:32, remaining: 6:16:30)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 22800-22899 to steam_app_data.csv. Batch 131 time: 0:02:48 (avg: 0:02:32, remaining: 6:14:16)
# Exported lines 22900-22999 to steam_app_data.csv. Batch 132 time: 0:02:17 (avg: 0:02:32, remaining: 6:11:28)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 23000-23099 to steam_app_data.csv. Batch 133 time: 0:02:47 (avg: 0:02:32, remaining: 6:09:14)
# Exported lines 23100-23199 to steam_app_data.csv. Batch 134 time: 0:02:16 (avg: 0:02:32, remaining: 6:06:25)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 23200-23299 to steam_app_data.csv. Batch 135 time: 0:02:46 (avg: 0:02:32, remaining: 6:04:08)
# Exported lines 23300-23399 to steam_app_data.csv. Batch 136 time: 0:02:18 (avg: 0:02:32, remaining: 6:01:22)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 23400-23499 to steam_app_data.csv. Batch 137 time: 0:02:49 (avg: 0:02:32, remaining: 5:59:09)
# Exported lines 23500-23599 to steam_app_data.csv. Batch 138 time: 0:02:17 (avg: 0:02:32, remaining: 5:56:22)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 23600-23699 to steam_app_data.csv. Batch 139 time: 0:03:00 (avg: 0:02:32, remaining: 5:54:18)
# Exported lines 23700-23799 to steam_app_data.csv. Batch 140 time: 0:02:18 (avg: 0:02:32, remaining: 5:51:32)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 23800-23899 to steam_app_data.csv. Batch 141 time: 0:02:48 (avg: 0:02:32, remaining: 5:49:16)
# Exported lines 23900-23999 to steam_app_data.csv. Batch 142 time: 0:02:17 (avg: 0:02:32, remaining: 5:46:30)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 24000-24099 to steam_app_data.csv. Batch 143 time: 0:02:48 (avg: 0:02:32, remaining: 5:44:14)
# Exported lines 24100-24199 to steam_app_data.csv. Batch 144 time: 0:02:17 (avg: 0:02:32, remaining: 5:41:28)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 24200-24299 to steam_app_data.csv. Batch 145 time: 0:02:46 (avg: 0:02:32, remaining: 5:39:10)
# Exported lines 24300-24399 to steam_app_data.csv. Batch 146 time: 0:02:15 (avg: 0:02:32, remaining: 5:36:23)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 24400-24499 to steam_app_data.csv. Batch 147 time: 0:02:46 (avg: 0:02:32, remaining: 5:34:04)
# Exported lines 24500-24599 to steam_app_data.csv. Batch 148 time: 0:02:18 (avg: 0:02:32, remaining: 5:31:20)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 24600-24699 to steam_app_data.csv. Batch 149 time: 0:02:47 (avg: 0:02:32, remaining: 5:29:02)
# Exported lines 24700-24799 to steam_app_data.csv. Batch 150 time: 0:02:18 (avg: 0:02:32, remaining: 5:26:18)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 24800-24899 to steam_app_data.csv. Batch 151 time: 0:02:47 (avg: 0:02:32, remaining: 5:23:59)
# Exported lines 24900-24999 to steam_app_data.csv. Batch 152 time: 0:02:17 (avg: 0:02:32, remaining: 5:21:15)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 25000-25099 to steam_app_data.csv. Batch 153 time: 0:02:50 (avg: 0:02:32, remaining: 5:18:58)
# Exported lines 25100-25199 to steam_app_data.csv. Batch 154 time: 0:02:16 (avg: 0:02:32, remaining: 5:16:13)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 25200-25299 to steam_app_data.csv. Batch 155 time: 0:02:48 (avg: 0:02:32, remaining: 5:13:54)
# Exported lines 25300-25399 to steam_app_data.csv. Batch 156 time: 0:02:17 (avg: 0:02:32, remaining: 5:11:10)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 25400-25499 to steam_app_data.csv. Batch 157 time: 0:02:47 (avg: 0:02:32, remaining: 5:08:50)
# Exported lines 25500-25599 to steam_app_data.csv. Batch 158 time: 0:02:16 (avg: 0:02:32, remaining: 5:06:07)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 25600-25699 to steam_app_data.csv. Batch 159 time: 0:02:45 (avg: 0:02:32, remaining: 5:03:45)
# Exported lines 25700-25799 to steam_app_data.csv. Batch 160 time: 0:02:16 (avg: 0:02:32, remaining: 5:01:01)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 25800-25899 to steam_app_data.csv. Batch 161 time: 0:02:46 (avg: 0:02:32, remaining: 4:58:40)
# Exported lines 25900-25999 to steam_app_data.csv. Batch 162 time: 0:02:17 (avg: 0:02:32, remaining: 4:55:57)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 26000-26099 to steam_app_data.csv. Batch 163 time: 0:02:47 (avg: 0:02:32, remaining: 4:53:36)
# Exported lines 26100-26199 to steam_app_data.csv. Batch 164 time: 0:02:17 (avg: 0:02:32, remaining: 4:50:54)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 26200-26299 to steam_app_data.csv. Batch 165 time: 0:02:47 (avg: 0:02:32, remaining: 4:48:33)
# Exported lines 26300-26399 to steam_app_data.csv. Batch 166 time: 0:02:17 (avg: 0:02:32, remaining: 4:45:51)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 26400-26499 to steam_app_data.csv. Batch 167 time: 0:02:47 (avg: 0:02:32, remaining: 4:43:29)
# Exported lines 26500-26599 to steam_app_data.csv. Batch 168 time: 0:02:16 (avg: 0:02:32, remaining: 4:40:47)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 26600-26699 to steam_app_data.csv. Batch 169 time: 0:02:51 (avg: 0:02:32, remaining: 4:38:28)
# Exported lines 26700-26799 to steam_app_data.csv. Batch 170 time: 0:02:17 (avg: 0:02:32, remaining: 4:35:46)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 26800-26899 to steam_app_data.csv. Batch 171 time: 0:02:48 (avg: 0:02:32, remaining: 4:33:25)
# Exported lines 26900-26999 to steam_app_data.csv. Batch 172 time: 0:02:21 (avg: 0:02:32, remaining: 4:30:46)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 27000-27099 to steam_app_data.csv. Batch 173 time: 0:02:50 (avg: 0:02:32, remaining: 4:28:25)
# Exported lines 27100-27199 to steam_app_data.csv. Batch 174 time: 0:02:18 (avg: 0:02:32, remaining: 4:25:45)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 27200-27299 to steam_app_data.csv. Batch 175 time: 0:02:49 (avg: 0:02:32, remaining: 4:23:23)
# Exported lines 27300-27399 to steam_app_data.csv. Batch 176 time: 0:02:19 (avg: 0:02:32, remaining: 4:20:44)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 27400-27499 to steam_app_data.csv. Batch 177 time: 0:02:50 (avg: 0:02:32, remaining: 4:18:22)
# Exported lines 27500-27599 to steam_app_data.csv. Batch 178 time: 0:02:21 (avg: 0:02:32, remaining: 4:15:44)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 27600-27699 to steam_app_data.csv. Batch 179 time: 0:02:49 (avg: 0:02:32, remaining: 4:13:22)
# Exported lines 27700-27799 to steam_app_data.csv. Batch 180 time: 0:02:17 (avg: 0:02:32, remaining: 4:10:41)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 27800-27899 to steam_app_data.csv. Batch 181 time: 0:02:53 (avg: 0:02:32, remaining: 4:08:21)
# Exported lines 27900-27999 to steam_app_data.csv. Batch 182 time: 0:02:18 (avg: 0:02:32, remaining: 4:05:41)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 28000-28099 to steam_app_data.csv. Batch 183 time: 0:02:48 (avg: 0:02:32, remaining: 4:03:18)
# Exported lines 28100-28199 to steam_app_data.csv. Batch 184 time: 0:02:22 (avg: 0:02:32, remaining: 4:00:40)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 28200-28299 to steam_app_data.csv. Batch 185 time: 0:02:48 (avg: 0:02:32, remaining: 3:58:17)
# Exported lines 28300-28399 to steam_app_data.csv. Batch 186 time: 0:02:20 (avg: 0:02:32, remaining: 3:55:38)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 28400-28499 to steam_app_data.csv. Batch 187 time: 0:02:46 (avg: 0:02:32, remaining: 3:53:13)
# Exported lines 28500-28599 to steam_app_data.csv. Batch 188 time: 0:02:27 (avg: 0:02:32, remaining: 3:50:39)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 28600-28699 to steam_app_data.csv. Batch 189 time: 0:02:47 (avg: 0:02:32, remaining: 3:48:14)
# Exported lines 28700-28799 to steam_app_data.csv. Batch 190 time: 0:02:22 (avg: 0:02:32, remaining: 3:45:37)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 28800-28899 to steam_app_data.csv. Batch 191 time: 0:02:47 (avg: 0:02:32, remaining: 3:43:12)
# Exported lines 28900-28999 to steam_app_data.csv. Batch 192 time: 0:02:18 (avg: 0:02:32, remaining: 3:40:34)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 29000-29099 to steam_app_data.csv. Batch 193 time: 0:02:52 (avg: 0:02:32, remaining: 3:38:10)
# Exported lines 29100-29199 to steam_app_data.csv. Batch 194 time: 0:02:19 (avg: 0:02:32, remaining: 3:35:32)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 29200-29299 to steam_app_data.csv. Batch 195 time: 0:02:51 (avg: 0:02:32, remaining: 3:33:08)
# Exported lines 29300-29399 to steam_app_data.csv. Batch 196 time: 0:02:20 (avg: 0:02:32, remaining: 3:30:31)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 29400-29499 to steam_app_data.csv. Batch 197 time: 0:02:46 (avg: 0:02:32, remaining: 3:28:04)
# Exported lines 29500-29599 to steam_app_data.csv. Batch 198 time: 0:02:17 (avg: 0:02:32, remaining: 3:25:26)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 29600-29699 to steam_app_data.csv. Batch 199 time: 0:02:48 (avg: 0:02:32, remaining: 3:23:00)
# Exported lines 29700-29799 to steam_app_data.csv. Batch 200 time: 0:02:21 (avg: 0:02:32, remaining: 3:20:24)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 29800-29899 to steam_app_data.csv. Batch 201 time: 0:02:50 (avg: 0:02:32, remaining: 3:17:58)
# Exported lines 29900-29999 to steam_app_data.csv. Batch 202 time: 0:02:20 (avg: 0:02:32, remaining: 3:15:21)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 30000-30099 to steam_app_data.csv. Batch 203 time: 0:02:48 (avg: 0:02:32, remaining: 3:12:55)
# Exported lines 30100-30199 to steam_app_data.csv. Batch 204 time: 0:02:18 (avg: 0:02:32, remaining: 3:10:17)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 30200-30299 to steam_app_data.csv. Batch 205 time: 0:02:48 (avg: 0:02:32, remaining: 3:07:51)
# Exported lines 30300-30399 to steam_app_data.csv. Batch 206 time: 0:02:19 (avg: 0:02:32, remaining: 3:05:14)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 30400-30499 to steam_app_data.csv. Batch 207 time: 0:02:49 (avg: 0:02:32, remaining: 3:02:48)
# Exported lines 30500-30599 to steam_app_data.csv. Batch 208 time: 0:02:18 (avg: 0:02:32, remaining: 3:00:10)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 30600-30699 to steam_app_data.csv. Batch 209 time: 0:02:55 (avg: 0:02:32, remaining: 2:57:46)
# Exported lines 30700-30799 to steam_app_data.csv. Batch 210 time: 0:02:19 (avg: 0:02:32, remaining: 2:55:09)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 30800-30899 to steam_app_data.csv. Batch 211 time: 0:02:46 (avg: 0:02:32, remaining: 2:52:41)
# Exported lines 30900-30999 to steam_app_data.csv. Batch 212 time: 0:02:17 (avg: 0:02:32, remaining: 2:50:04)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 31000-31099 to steam_app_data.csv. Batch 213 time: 0:02:47 (avg: 0:02:32, remaining: 2:47:36)
# Exported lines 31100-31199 to steam_app_data.csv. Batch 214 time: 0:02:18 (avg: 0:02:32, remaining: 2:44:59)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 31200-31299 to steam_app_data.csv. Batch 215 time: 0:02:47 (avg: 0:02:32, remaining: 2:42:31)
# Exported lines 31300-31399 to steam_app_data.csv. Batch 216 time: 0:02:18 (avg: 0:02:32, remaining: 2:39:54)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 31400-31499 to steam_app_data.csv. Batch 217 time: 0:02:48 (avg: 0:02:32, remaining: 2:37:27)
# Exported lines 31500-31599 to steam_app_data.csv. Batch 218 time: 0:02:17 (avg: 0:02:32, remaining: 2:34:50)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 31600-31699 to steam_app_data.csv. Batch 219 time: 0:02:47 (avg: 0:02:32, remaining: 2:32:22)
# Exported lines 31700-31799 to steam_app_data.csv. Batch 220 time: 0:02:18 (avg: 0:02:32, remaining: 2:29:46)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 31800-31899 to steam_app_data.csv. Batch 221 time: 0:02:50 (avg: 0:02:32, remaining: 2:27:18)
# Exported lines 31900-31999 to steam_app_data.csv. Batch 222 time: 0:02:16 (avg: 0:02:32, remaining: 2:24:41)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 32000-32099 to steam_app_data.csv. Batch 223 time: 0:02:49 (avg: 0:02:32, remaining: 2:22:13)
# Exported lines 32100-32199 to steam_app_data.csv. Batch 224 time: 0:02:16 (avg: 0:02:32, remaining: 2:19:37)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 32200-32299 to steam_app_data.csv. Batch 225 time: 0:02:51 (avg: 0:02:32, remaining: 2:17:09)
# Exported lines 32300-32399 to steam_app_data.csv. Batch 226 time: 0:02:19 (avg: 0:02:32, remaining: 2:14:33)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 32400-32499 to steam_app_data.csv. Batch 227 time: 0:02:50 (avg: 0:02:32, remaining: 2:12:05)
# Exported lines 32500-32599 to steam_app_data.csv. Batch 228 time: 0:02:16 (avg: 0:02:32, remaining: 2:09:29)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 32600-32699 to steam_app_data.csv. Batch 229 time: 0:02:48 (avg: 0:02:32, remaining: 2:07:00)
# Exported lines 32700-32799 to steam_app_data.csv. Batch 230 time: 0:02:19 (avg: 0:02:32, remaining: 2:04:25)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 32800-32899 to steam_app_data.csv. Batch 231 time: 0:02:51 (avg: 0:02:32, remaining: 2:01:57)
# Exported lines 32900-32999 to steam_app_data.csv. Batch 232 time: 0:02:19 (avg: 0:02:32, remaining: 1:59:21)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 33000-33099 to steam_app_data.csv. Batch 233 time: 0:02:49 (avg: 0:02:32, remaining: 1:56:52)
# Exported lines 33100-33199 to steam_app_data.csv. Batch 234 time: 0:02:22 (avg: 0:02:32, remaining: 1:54:18)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 33200-33299 to steam_app_data.csv. Batch 235 time: 0:02:48 (avg: 0:02:32, remaining: 1:51:48)
# Exported lines 33300-33399 to steam_app_data.csv. Batch 236 time: 0:02:18 (avg: 0:02:32, remaining: 1:49:13)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 33400-33499 to steam_app_data.csv. Batch 237 time: 0:02:49 (avg: 0:02:32, remaining: 1:46:44)
# Exported lines 33500-33599 to steam_app_data.csv. Batch 238 time: 0:02:25 (avg: 0:02:32, remaining: 1:44:10)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 33600-33699 to steam_app_data.csv. Batch 239 time: 0:03:08 (avg: 0:02:33, remaining: 1:41:43)
# Exported lines 33700-33799 to steam_app_data.csv. Batch 240 time: 0:02:19 (avg: 0:02:33, remaining: 1:39:09)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 33800-33899 to steam_app_data.csv. Batch 241 time: 0:02:48 (avg: 0:02:33, remaining: 1:36:38)
# Exported lines 33900-33999 to steam_app_data.csv. Batch 242 time: 0:02:17 (avg: 0:02:33, remaining: 1:34:04)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 34000-34099 to steam_app_data.csv. Batch 243 time: 0:02:48 (avg: 0:02:33, remaining: 1:31:33)
# Exported lines 34100-34199 to steam_app_data.csv. Batch 244 time: 0:02:16 (avg: 0:02:33, remaining: 1:28:58)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 34200-34299 to steam_app_data.csv. Batch 245 time: 0:02:48 (avg: 0:02:33, remaining: 1:26:28)
# Exported lines 34300-34399 to steam_app_data.csv. Batch 246 time: 0:02:18 (avg: 0:02:33, remaining: 1:23:53)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 34400-34499 to steam_app_data.csv. Batch 247 time: 0:02:48 (avg: 0:02:33, remaining: 1:21:23)
# Exported lines 34500-34599 to steam_app_data.csv. Batch 248 time: 0:02:18 (avg: 0:02:33, remaining: 1:18:48)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 34600-34699 to steam_app_data.csv. Batch 249 time: 0:02:48 (avg: 0:02:33, remaining: 1:16:18)
# Exported lines 34700-34799 to steam_app_data.csv. Batch 250 time: 0:02:18 (avg: 0:02:33, remaining: 1:13:44)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 34800-34899 to steam_app_data.csv. Batch 251 time: 0:02:48 (avg: 0:02:33, remaining: 1:11:13)
# Exported lines 34900-34999 to steam_app_data.csv. Batch 252 time: 0:02:16 (avg: 0:02:33, remaining: 1:08:39)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 35000-35099 to steam_app_data.csv. Batch 253 time: 0:02:48 (avg: 0:02:33, remaining: 1:06:08)
# Exported lines 35100-35199 to steam_app_data.csv. Batch 254 time: 0:02:18 (avg: 0:02:33, remaining: 1:03:34)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 35200-35299 to steam_app_data.csv. Batch 255 time: 0:02:48 (avg: 0:02:33, remaining: 1:01:02)
# Exported lines 35300-35399 to steam_app_data.csv. Batch 256 time: 0:02:19 (avg: 0:02:33, remaining: 0:58:29)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 35400-35499 to steam_app_data.csv. Batch 257 time: 0:02:50 (avg: 0:02:33, remaining: 0:55:57)
# Exported lines 35500-35599 to steam_app_data.csv. Batch 258 time: 0:02:18 (avg: 0:02:33, remaining: 0:53:24)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 35600-35699 to steam_app_data.csv. Batch 259 time: 0:02:47 (avg: 0:02:33, remaining: 0:50:52)
# Exported lines 35700-35799 to steam_app_data.csv. Batch 260 time: 0:02:18 (avg: 0:02:33, remaining: 0:48:19)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 35800-35899 to steam_app_data.csv. Batch 261 time: 0:02:48 (avg: 0:02:33, remaining: 0:45:47)
# Exported lines 35900-35999 to steam_app_data.csv. Batch 262 time: 0:02:17 (avg: 0:02:33, remaining: 0:43:13)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 36000-36099 to steam_app_data.csv. Batch 263 time: 0:02:52 (avg: 0:02:33, remaining: 0:40:42)
# Exported lines 36100-36199 to steam_app_data.csv. Batch 264 time: 0:02:19 (avg: 0:02:33, remaining: 0:38:09)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 36200-36299 to steam_app_data.csv. Batch 265 time: 0:02:46 (avg: 0:02:33, remaining: 0:35:37)
# Exported lines 36300-36399 to steam_app_data.csv. Batch 266 time: 0:02:17 (avg: 0:02:33, remaining: 0:33:03)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 36400-36499 to steam_app_data.csv. Batch 267 time: 0:02:49 (avg: 0:02:33, remaining: 0:30:32)
# Exported lines 36500-36599 to steam_app_data.csv. Batch 268 time: 0:02:18 (avg: 0:02:33, remaining: 0:27:58)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 36600-36699 to steam_app_data.csv. Batch 269 time: 0:02:49 (avg: 0:02:33, remaining: 0:25:26)
# Exported lines 36700-36799 to steam_app_data.csv. Batch 270 time: 0:02:18 (avg: 0:02:33, remaining: 0:22:53)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 36800-36899 to steam_app_data.csv. Batch 271 time: 0:02:47 (avg: 0:02:33, remaining: 0:20:21)
# Exported lines 36900-36999 to steam_app_data.csv. Batch 272 time: 0:02:20 (avg: 0:02:33, remaining: 0:17:48)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 37000-37099 to steam_app_data.csv. Batch 273 time: 0:02:50 (avg: 0:02:33, remaining: 0:15:16)
# Exported lines 37100-37199 to steam_app_data.csv. Batch 274 time: 0:02:18 (avg: 0:02:33, remaining: 0:12:43)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 37200-37299 to steam_app_data.csv. Batch 275 time: 0:02:46 (avg: 0:02:33, remaining: 0:10:11)
# Exported lines 37300-37399 to steam_app_data.csv. Batch 276 time: 0:02:17 (avg: 0:02:33, remaining: 0:07:38)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 37400-37499 to steam_app_data.csv. Batch 277 time: 0:02:48 (avg: 0:02:33, remaining: 0:05:05)
# Exported lines 37500-37599 to steam_app_data.csv. Batch 278 time: 0:02:18 (avg: 0:02:33, remaining: 0:02:33)
# No response, waiting 30 seconds...
# Retrying.
# Exported lines 37600-37684 to steam_app_data.csv. Batch 279 time: 0:02:26 (avg: 0:02:33, remaining: 0:00:00)
#
# Processing batches complete. 27984 apps written

# %%
# Set end and chunksize for demonstration - remove to run through entire app list
process_batches(
    parser=parse_steam_request,
    app_list=app_list,
    download_path=download_path,
    data_filename=steam_app_data,
    index_filename=steam_index,
    columns=steam_columns,
    begin=index,
    #end=10,
    #batchsize=5

# %%
df = pd.read_csv('../data/download/steam_app_data.csv', delimiter=';', encoding='latin1')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-39-9cfa3cba1e42> in <module>
# ----> 1 df = pd.read_csv('../data/download/steam_app_data.csv', delimiter=';', encoding='latin1')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     try:
# --> 463         data = parser.read(nrows)
#     464     finally:
#     465         parser.close()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1152     def read(self, nrows=None):
#    1153         nrows = _validate_integer("nrows", nrows)
# -> 1154         ret = self._engine.read(nrows)
#    1155
#    1156         # May alter columns / col_dict
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2057     def read(self, nrows=None):
#    2058         try:
# -> 2059             data = self._reader.read(nrows)
#    2060         except StopIteration:
#    2061             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 43, saw 2

# %%
def parse_steamspy_request(appid, name):
    """Parser to handle SteamSpy API data."""
    url = "https://steamspy.com/api.php"
    parameters = {"request": "appdetails", "appid": appid}
    
    json_data = get_request(url, parameters)
    return json_data


# set files and columns
download_path = '../data/download'
steamspy_data = 'steamspy_data.csv'
steamspy_index = 'steamspy_index.txt'

steamspy_columns = [
    'appid', 'name', 'developer', 'publisher', 'score_rank', 'positive',
    'negative', 'userscore', 'owners', 'average_forever', 'average_2weeks',
    'median_forever', 'median_2weeks', 'price', 'initialprice', 'discount',
    'languages', 'genre', 'ccu', 'tags'
]

reset_index(download_path, steamspy_index)
index = get_index(download_path, steamspy_index)

# Wipe data file if index is 0
prepare_data_file(download_path, steamspy_data, index, steamspy_columns)

process_batches(
    parser=parse_steamspy_request,
    app_list=app_list,
    download_path=download_path, 
    data_filename=steamspy_data,
    index_filename=steamspy_index,
    columns=steamspy_columns,
    begin=index,
    end=20,
    batchsize=5,
    pause=0.3
)
# Out:
# Starting at index 0:
#
# Exported lines 0-4 to steamspy_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 0:00:14)
# Exported lines 5-9 to steamspy_data.csv. Batch 1 time: 0:00:04 (avg: 0:00:05, remaining: 0:00:09)
# Exported lines 10-14 to steamspy_data.csv. Batch 2 time: 0:00:04 (avg: 0:00:04, remaining: 0:00:04)
# Exported lines 15-19 to steamspy_data.csv. Batch 3 time: 0:00:04 (avg: 0:00:04, remaining: 0:00:00)
#
# Processing batches complete. 20 apps written

# %%
pd.read_csv('../data/download/steamspy_data.csv').head()
# Out:
#    appid                       name         developer publisher  score_rank  \
# 0     10             Counter-Strike             Valve     Valve         NaN
# 1     20      Team Fortress Classic             Valve     Valve         NaN
# 2     30              Day of Defeat             Valve     Valve         NaN
# 3     40         Deathmatch Classic             Valve     Valve         NaN
# 4     50  Half-Life: Opposing Force  Gearbox Software     Valve         NaN
#
#    positive  negative  userscore                    owners  average_forever  \
# 0    159654      4174          0  10,000,000 .. 20,000,000            19751
# 1      4333       771          0    2,000,000 .. 5,000,000              797
# 2      4322       483          0   5,000,000 .. 10,000,000              882
# 3      1591       345          0   5,000,000 .. 10,000,000             1187
# 4      8886       475          0   5,000,000 .. 10,000,000             1112
#
#    average_2weeks  median_forever  median_2weeks  price  initialprice  \
# 0            1498             181            264    999           999
# 1               0               9              0    499           499
# 2               0              19              0    499           499
# 3               0               8              0    499           499
# 4             391             181            391    499           499
#
#    discount                                          languages   genre    ccu  \
# 0         0  English, French, German, Italian, Spanish - Sp...  Action  12975
# 1         0  English, French, German, Italian, Spanish - Sp...  Action    114
# 2         0  English, French, German, Italian, Spanish - Spain  Action    139
# 3         0  English, French, German, Italian, Spanish - Sp...  Action      6
# 4         0                    English, French, German, Korean  Action    117
#
#                                                 tags
# 0  {'Action': 5314, 'FPS': 4718, 'Multiplayer': 3...
# 1  {'Action': 731, 'FPS': 297, 'Multiplayer': 251...
# 2  {'FPS': 777, 'World War II': 242, 'Multiplayer...
# 3  {'Action': 624, 'FPS': 135, 'Classic': 103, 'M...
# 4  {'FPS': 869, 'Action': 310, 'Classic': 237, 'S...
