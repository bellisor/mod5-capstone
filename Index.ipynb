# %%
#UTILITIES
import pandas as pd 
import numpy as np 
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

from ast import literal_eval
import itertools
import time
import re

#MACHINE LEARNING
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor, VotingRegressor, RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Arial'],'size':'14'}) 

#Some Settings

pd.set_option('display.max_columns', 100)

RANDOM_STATE = len('I used to be an adventurer like you') #Bu I took an arrow to the knee.

# %%
#Data import

#Kaggle Dataset of 200k steam games by user (this will be used for recommendations)
steam_200k = pd.read_csv('data/Kaggle/steam-200k.csv')
#Dataset gathered using steam API
raw_steam = pd.read_csv('data/Kaggle/steam_app_data.csv')
#Steam Spy API
steam_spy = pd.read_csv('data/Kaggle/steamspy_data.csv')
#Proprietary Dataset
steam_df = pd.read_csv('data/Kaggle/df_for_data.csv')

# %%
raw_steam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29235 entries, 0 to 29234
# Data columns (total 39 columns):
# type                       29086 non-null object
# name                       29234 non-null object
# steam_appid                29235 non-null int64
# required_age               29086 non-null float64
# is_free                    29086 non-null object
# controller_support         5998 non-null object
# dlc                        4975 non-null object
# detailed_description       29060 non-null object
# about_the_game             29060 non-null object
# short_description          29060 non-null object
# fullgame                   0 non-null float64
# supported_languages        29072 non-null object
# header_image               29086 non-null object
# website                    19252 non-null object
# pc_requirements            29086 non-null object
# mac_requirements           29086 non-null object
# linux_requirements         29086 non-null object
# legal_notice               10067 non-null object
# drm_notice                 158 non-null object
# ext_user_account_notice    512 non-null object
# developers                 28971 non-null object
# publishers                 29086 non-null object
# demos                      2139 non-null object
# price_overview             25523 non-null object
# packages                   25865 non-null object
# package_groups             29086 non-null object
# platforms                  29086 non-null object
# metacritic                 2981 non-null object
# reviews                    5905 non-null object
# categories                 28521 non-null object
# genres                     29039 non-null object
# screenshots                29058 non-null object
# movies                     27157 non-null object
# recommendations            6728 non-null object
# achievements               26854 non-null object
# release_date               29086 non-null object
# support_info               29086 non-null object
# background                 29058 non-null object
# content_descriptors        29086 non-null object
# dtypes: float64(2), int64(1), object(36)
# memory usage: 8.7+ MB

# %%
raw_steam.head()
# Out:
#    type                       name  steam_appid  required_age is_free  \
# 0  game             Counter-Strike           10           0.0   False
# 1  game      Team Fortress Classic           20           0.0   False
# 2  game              Day of Defeat           30           0.0   False
# 3  game         Deathmatch Classic           40           0.0   False
# 4  game  Half-Life: Opposing Force           50           0.0   False
#
#   controller_support  dlc                               detailed_description  \
# 0                NaN  NaN  Play the world's number 1 online action game. ...
# 1                NaN  NaN  One of the most popular online action games of...
# 2                NaN  NaN  Enlist in an intense brand of Axis vs. Allied ...
# 3                NaN  NaN  Enjoy fast-paced multiplayer gaming with Death...
# 4                NaN  NaN  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  fullgame  \
# 0  Play the world's number 1 online action game. ...       NaN
# 1  One of the most popular online action games of...       NaN
# 2  Enlist in an intense brand of Axis vs. Allied ...       NaN
# 3  Enjoy fast-paced multiplayer gaming with Death...       NaN
# 4  Return to the Black Mesa Research Facility as ...       NaN
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements legal_notice drm_notice  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
#
#   ext_user_account_notice            developers publishers demos  \
# 0                     NaN             ['Valve']  ['Valve']   NaN
# 1                     NaN             ['Valve']  ['Valve']   NaN
# 2                     NaN             ['Valve']  ['Valve']   NaN
# 3                     NaN             ['Valve']  ['Valve']   NaN
# 4                     NaN  ['Gearbox Software']  ['Valve']   NaN
#
#                                       price_overview packages  \
# 0  {'currency': 'GBP', 'initial': 719, 'final': 7...      [7]
# 1  {'currency': 'GBP', 'initial': 399, 'final': 3...     [29]
# 2  {'currency': 'GBP', 'initial': 399, 'final': 3...     [30]
# 3  {'currency': 'GBP', 'initial': 399, 'final': 3...     [31]
# 4  {'currency': 'GBP', 'initial': 399, 'final': 3...     [32]
#
#                                       package_groups  \
# 0  [{'name': 'default', 'title': 'Buy Counter-Str...
# 1  [{'name': 'default', 'title': 'Buy Team Fortre...
# 2  [{'name': 'default', 'title': 'Buy Day of Defe...
# 3  [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4  [{'name': 'default', 'title': 'Buy Half-Life: ...
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           metacritic reviews  \
# 0  {'score': 88, 'url': 'https://www.metacritic.c...     NaN
# 1                                                NaN     NaN
# 2  {'score': 79, 'url': 'https://www.metacritic.c...     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies   recommendations  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 65735}
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 2802}
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 1992}
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN    {'total': 931}
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN   {'total': 4355}
#
#    achievements                                   release_date  \
# 0  {'total': 0}  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'total': 0}  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'total': 0}  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'total': 0}  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'total': 0}  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                  content_descriptors
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                         {'ids': [], 'notes': None}
# 3                         {'ids': [], 'notes': None}
# 4                         {'ids': [], 'notes': None}

# %% [markdown]
# ## Data Cleaning

# %%
null = raw_steam.isnull().sum()
null
# Out:
# type                         149
# name                           1
# steam_appid                    0
# required_age                 149
# is_free                      149
# controller_support         23237
# dlc                        24260
# detailed_description         175
# about_the_game               175
# short_description            175
# fullgame                   29235
# supported_languages          163
# header_image                 149
# website                     9983
# pc_requirements              149
# mac_requirements             149
# linux_requirements           149
# legal_notice               19168
# drm_notice                 29077
# ext_user_account_notice    28723
# developers                   264
# publishers                   149
# demos                      27096
# price_overview              3712
# packages                    3370
# package_groups               149
# platforms                    149
# metacritic                 26254
# reviews                    23330
# categories                   714
# genres                       196
# screenshots                  177
# movies                      2078
# recommendations            22507
# achievements                2381
# release_date                 149
# support_info                 149
# background                   177
# content_descriptors          149
# dtype: int64

# %% [markdown]
# There are severl columns missing more than half of the information. Since these wont help us we're going to drop each of these columns.

# %%
#Set a threshold for dropping null values

threshold = raw_steam.shape[0] // 2
print('the threshold is:', threshold)
# Out:
# the threshold is: 14617

# %%
#Get a list of columns to drop
drop_col = raw_steam.columns[null > threshold]

# %%
print('Columns to drop: {}'.format(list(drop_col)))
# Out:
# Columns to drop: ['controller_support', 'dlc', 'fullgame', 'legal_notice', 'drm_notice', 'ext_user_account_notice', 'demos', 'metacritic', 'reviews', 'recommendations']

# %%
print('Rows to remove:', raw_steam[raw_steam['type'].isnull()].shape[0])

raw_steam[raw_steam['type'].isnull()].head()
# Out:
# Rows to remove: 149
#     type                       name  steam_appid  required_age is_free  \
# 26   NaN  Half-Life: Opposing Force          852           NaN     NaN
# 147  NaN  Half-Life: Opposing Force         4330           NaN     NaN
# 256  NaN  Half-Life: Opposing Force         8740           NaN     NaN
# 264  NaN  Half-Life: Opposing Force         8955           NaN     NaN
# 336  NaN  Half-Life: Opposing Force        11610           NaN     NaN
#
#     controller_support  dlc detailed_description about_the_game  \
# 26                 NaN  NaN                  NaN            NaN
# 147                NaN  NaN                  NaN            NaN
# 256                NaN  NaN                  NaN            NaN
# 264                NaN  NaN                  NaN            NaN
# 336                NaN  NaN                  NaN            NaN
#
#     short_description  fullgame supported_languages header_image website  \
# 26                NaN       NaN                 NaN          NaN     NaN
# 147               NaN       NaN                 NaN          NaN     NaN
# 256               NaN       NaN                 NaN          NaN     NaN
# 264               NaN       NaN                 NaN          NaN     NaN
# 336               NaN       NaN                 NaN          NaN     NaN
#
#     pc_requirements mac_requirements linux_requirements legal_notice  \
# 26              NaN              NaN                NaN          NaN
# 147             NaN              NaN                NaN          NaN
# 256             NaN              NaN                NaN          NaN
# 264             NaN              NaN                NaN          NaN
# 336             NaN              NaN                NaN          NaN
#
#     drm_notice ext_user_account_notice developers publishers demos  \
# 26         NaN                     NaN        NaN        NaN   NaN
# 147        NaN                     NaN        NaN        NaN   NaN
# 256        NaN                     NaN        NaN        NaN   NaN
# 264        NaN                     NaN        NaN        NaN   NaN
# 336        NaN                     NaN        NaN        NaN   NaN
#
#     price_overview packages package_groups platforms metacritic reviews  \
# 26             NaN      NaN            NaN       NaN        NaN     NaN
# 147            NaN      NaN            NaN       NaN        NaN     NaN
# 256            NaN      NaN            NaN       NaN        NaN     NaN
# 264            NaN      NaN            NaN       NaN        NaN     NaN
# 336            NaN      NaN            NaN       NaN        NaN     NaN
#
#     categories genres screenshots movies recommendations achievements  \
# 26         NaN    NaN         NaN    NaN             NaN          NaN
# 147        NaN    NaN         NaN    NaN             NaN          NaN
# 256        NaN    NaN         NaN    NaN             NaN          NaN
# 264        NaN    NaN         NaN    NaN             NaN          NaN
# 336        NaN    NaN         NaN    NaN             NaN          NaN
#
#     release_date support_info background content_descriptors
# 26           NaN          NaN        NaN                 NaN
# 147          NaN          NaN        NaN                 NaN
# 256          NaN          NaN        NaN                 NaN
# 264          NaN          NaN        NaN                 NaN
# 336          NaN          NaN        NaN                 NaN

# %%
#Check Value Counts
raw_steam['type'].value_counts(dropna=False)
# Out:
# game    29086
# NaN       149
# Name: type, dtype: int64

# %% [markdown]
# This matches the above so we're cleared to proceed

# %%
#Moving on to name column, check for missing game names

missing_names = raw_steam[(raw_steam['name'].isnull()) | (raw_steam['name'] == 'none')]
missing_names
# Out:
#       type  name  steam_appid  required_age is_free controller_support  dlc  \
# 4918  game  none       339860           0.0   False                NaN  NaN
# 6779  game  none       385020           0.0   False                NaN  NaN
# 7235  game   NaN       396420           0.0    True                NaN  NaN
# 7350  game  none       398970           0.0   False                NaN  NaN
#
#                                    detailed_description  \
# 4918                                                NaN
# 6779                   - discontinued - (please remove)
# 7235  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。<b...
# 7350                                                NaN
#
#                                          about_the_game  \
# 4918                                                NaN
# 6779                   - discontinued - (please remove)
# 7235  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。<b...
# 7350                                                NaN
#
#                                       short_description  fullgame  \
# 4918                                                NaN       NaN
# 6779                   - discontinued - (please remove)       NaN
# 7235  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。 村...       NaN
# 7350                                                NaN       NaN
#
#                                     supported_languages  \
# 4918  English<strong>*</strong><br><strong>*</strong...
# 6779  English, French, Italian, German, Spanish - Sp...
# 7235                                                NaN
# 7350  English<strong>*</strong><br><strong>*</strong...
#
#                                            header_image website  \
# 4918  https://steamcdn-a.akamaihd.net/steam/apps/339...     NaN
# 6779  https://steamcdn-a.akamaihd.net/steam/apps/385...     NaN
# 7235  https://steamcdn-a.akamaihd.net/steam/apps/396...     NaN
# 7350  https://steamcdn-a.akamaihd.net/steam/apps/398...     NaN
#
#                                         pc_requirements  \
# 4918  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 6779  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7235  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7350  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                        mac_requirements  \
# 4918                                                 []
# 6779  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7235                                                 []
# 7350  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                      linux_requirements legal_notice  \
# 4918                                                 []          NaN
# 6779  {'minimum': '<strong>Minimum:</strong><br><ul ...          NaN
# 7235                                                 []          NaN
# 7350  {'minimum': '<strong>Minimum:</strong><br><ul ...          NaN
#
#      drm_notice ext_user_account_notice developers publishers  \
# 4918        NaN                     NaN        NaN       ['']
# 6779        NaN                     NaN   ['none']       ['']
# 7235        NaN                     NaN        NaN       ['']
# 7350        NaN                     NaN   ['none']   ['none']
#
#                                        demos price_overview packages  \
# 4918                                     NaN            NaN      NaN
# 6779                                     NaN            NaN      NaN
# 7235                                     NaN            NaN      NaN
# 7350  [{'appid': 516340, 'description': ''}]            NaN      NaN
#
#      package_groups                                        platforms  \
# 4918             []  {'windows': True, 'mac': False, 'linux': False}
# 6779             []    {'windows': True, 'mac': True, 'linux': True}
# 7235             []  {'windows': True, 'mac': False, 'linux': False}
# 7350             []    {'windows': True, 'mac': True, 'linux': True}
#
#      metacritic reviews                                         categories  \
# 4918        NaN     NaN  [{'id': 2, 'description': 'Single-player'}, {'...
# 6779        NaN     NaN  [{'id': 2, 'description': 'Single-player'}, {'...
# 7235        NaN     NaN                                                NaN
# 7350        NaN     NaN  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                  genres screenshots movies  \
# 4918  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN    NaN
# 6779  [{'id': '4', 'description': 'Casual'}, {'id': ...         NaN    NaN
# 7235                                                NaN         NaN    NaN
# 7350  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN    NaN
#
#      recommendations                                       achievements  \
# 4918             NaN  {'total': 3, 'highlighted': [{'name': 'Master ...
# 6779             NaN                                       {'total': 0}
# 7235             NaN                                       {'total': 0}
# 7350             NaN  {'total': 35, 'highlighted': [{'name': "They'v...
#
#                                         release_date  \
# 4918  {'coming_soon': False, 'date': '27 Feb, 2015'}
# 6779   {'coming_soon': False, 'date': '4 Nov, 2015'}
# 7235   {'coming_soon': False, 'date': '1 Nov, 2016'}
# 7350   {'coming_soon': False, 'date': '5 Nov, 2015'}
#
#                   support_info background         content_descriptors
# 4918  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 6779  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 7235  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 7350  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}

# %% [markdown]
# Only four observations missing names (and a lot of other info) so we'll drop these too

# %%
duplicate_rows = raw_steam[raw_steam.duplicated()]

print('Dupicate rows to remove:', duplicate_rows.shape[0])

duplicate_rows.head()
# Out:
# Dupicate rows to remove: 7
#      type                     name  steam_appid  required_age is_free  \
# 31   game  SiN Episodes: Emergence         1300           0.0   False
# 32   game  SiN Episodes: Emergence         1300           0.0   False
# 356  game   Jagged Alliance 2 Gold         1620           0.0   False
# 493  game       Crazy Machines 1.5        18430           0.0   False
# 494  game       Crazy Machines 1.5        18430           0.0   False
#
#     controller_support  dlc  \
# 31                 NaN  NaN
# 32                 NaN  NaN
# 356                NaN  NaN
# 493                NaN  NaN
# 494                NaN  NaN
#
#                                   detailed_description  \
# 31   You are John Blade, commander of HardCorps, an...
# 32   You are John Blade, commander of HardCorps, an...
# 356  <p>The small country of Arulco has been taken ...
# 493  Create Your Own Zany &quot;Rube Goldberg&quot;...
# 494  Create Your Own Zany &quot;Rube Goldberg&quot;...
#
#                                         about_the_game  \
# 31   You are John Blade, commander of HardCorps, an...
# 32   You are John Blade, commander of HardCorps, an...
# 356  <p>The small country of Arulco has been taken ...
# 493  Create Your Own Zany &quot;Rube Goldberg&quot;...
# 494  Create Your Own Zany &quot;Rube Goldberg&quot;...
#
#                                      short_description  fullgame  \
# 31   You are John Blade, commander of HardCorps, an...       NaN
# 32   You are John Blade, commander of HardCorps, an...       NaN
# 356  The small country of Arulco has been taken ove...       NaN
# 493  Create Your Own Zany &quot;Rube Goldberg&quot;...       NaN
# 494  Create Your Own Zany &quot;Rube Goldberg&quot;...       NaN
#
#           supported_languages  \
# 31   English, Russian, French
# 32   English, Russian, French
# 356                   English
# 493                   English
# 494                   English
#
#                                           header_image  \
# 31   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 32   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 356  https://steamcdn-a.akamaihd.net/steam/apps/162...
# 493  https://steamcdn-a.akamaihd.net/steam/apps/184...
# 494  https://steamcdn-a.akamaihd.net/steam/apps/184...
#
#                              website  \
# 31                               NaN
# 32                               NaN
# 356  http://www.jaggedalliance2.com/
# 493                              NaN
# 494                              NaN
#
#                                        pc_requirements mac_requirements  \
# 31   {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...               []
# 32   {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...               []
# 356  {'minimum': '<p><strong>Minimum Configuration:...               []
# 493  {'minimum': '<ul class="bb_ul"><li><strong>OS:...               []
# 494  {'minimum': '<ul class="bb_ul"><li><strong>OS:...               []
#
#     linux_requirements legal_notice drm_notice ext_user_account_notice  \
# 31                  []          NaN        NaN                     NaN
# 32                  []          NaN        NaN                     NaN
# 356                 []          NaN        NaN                     NaN
# 493                 []          NaN        NaN                     NaN
# 494                 []          NaN        NaN                     NaN
#
#                    developers                publishers demos  \
# 31   ['Ritual Entertainment']  ['Ritual Entertainment']   NaN
# 32   ['Ritual Entertainment']  ['Ritual Entertainment']   NaN
# 356        ['Strategy First']        ['Strategy First']   NaN
# 493         ['Fakt Software']            ['Viva Media']   NaN
# 494         ['Fakt Software']            ['Viva Media']   NaN
#
#                                         price_overview       packages  \
# 31   {'currency': 'GBP', 'initial': 719, 'final': 7...           [70]
# 32   {'currency': 'GBP', 'initial': 719, 'final': 7...           [70]
# 356  {'currency': 'GBP', 'initial': 1499, 'final': ...           [94]
# 493  {'currency': 'GBP', 'initial': 699, 'final': 6...  [1242, 58401]
# 494  {'currency': 'GBP', 'initial': 699, 'final': 6...  [1242, 58401]
#
#                                         package_groups  \
# 31   [{'name': 'default', 'title': 'Buy SiN Episode...
# 32   [{'name': 'default', 'title': 'Buy SiN Episode...
# 356  [{'name': 'default', 'title': 'Buy Jagged Alli...
# 493  [{'name': 'default', 'title': 'Buy Crazy Machi...
# 494  [{'name': 'default', 'title': 'Buy Crazy Machi...
#
#                                            platforms  \
# 31   {'windows': True, 'mac': False, 'linux': False}
# 32   {'windows': True, 'mac': False, 'linux': False}
# 356  {'windows': True, 'mac': False, 'linux': False}
# 493  {'windows': True, 'mac': False, 'linux': False}
# 494  {'windows': True, 'mac': False, 'linux': False}
#
#                                             metacritic reviews  \
# 31   {'score': 75, 'url': 'https://www.metacritic.c...     NaN
# 32   {'score': 75, 'url': 'https://www.metacritic.c...     NaN
# 356                                                NaN     NaN
# 493  {'score': 78, 'url': 'https://www.metacritic.c...     NaN
# 494  {'score': 78, 'url': 'https://www.metacritic.c...     NaN
#
#                                             categories  \
# 31   [{'id': 2, 'description': 'Single-player'}, {'...
# 32   [{'id': 2, 'description': 'Single-player'}, {'...
# 356        [{'id': 2, 'description': 'Single-player'}]
# 493        [{'id': 2, 'description': 'Single-player'}]
# 494        [{'id': 2, 'description': 'Single-player'}]
#
#                                                 genres  \
# 31              [{'id': '1', 'description': 'Action'}]
# 32              [{'id': '1', 'description': 'Action'}]
# 356           [{'id': '2', 'description': 'Strategy'}]
# 493  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 494  [{'id': '4', 'description': 'Casual'}, {'id': ...
#
#                                            screenshots movies recommendations  \
# 31   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 265}
# 32   [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 265}
# 356  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             NaN
# 493  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             NaN
# 494  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN             NaN
#
#      achievements                                    release_date  \
# 31   {'total': 0}  {'coming_soon': False, 'date': '10 May, 2006'}
# 32   {'total': 0}  {'coming_soon': False, 'date': '10 May, 2006'}
# 356  {'total': 0}   {'coming_soon': False, 'date': '6 Jul, 2006'}
# 493  {'total': 0}  {'coming_soon': False, 'date': '12 Dec, 2008'}
# 494  {'total': 0}  {'coming_soon': False, 'date': '12 Dec, 2008'}
#
#                  support_info  \
# 31   {'url': '', 'email': ''}
# 32   {'url': '', 'email': ''}
# 356  {'url': '', 'email': ''}
# 493  {'url': '', 'email': ''}
# 494  {'url': '', 'email': ''}
#
#                                             background  \
# 31   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 32   https://steamcdn-a.akamaihd.net/steam/apps/130...
# 356  https://steamcdn-a.akamaihd.net/steam/apps/162...
# 493  https://steamcdn-a.akamaihd.net/steam/apps/184...
# 494  https://steamcdn-a.akamaihd.net/steam/apps/184...
#
#             content_descriptors
# 31   {'ids': [], 'notes': None}
# 32   {'ids': [], 'notes': None}
# 356  {'ids': [], 'notes': None}
# 493  {'ids': [], 'notes': None}
# 494  {'ids': [], 'notes': None}

# %% [markdown]
# Now its time to treat the null values (be gone demons)

# %%
def drop_null_cols(df, thresh=0.5):
    '''Drop columns with null values over the established threshold'''
    cutoff = len(df) * thresh
    
    return df.dropna(thresh=cutoff, axis = 1)

def drop_name_type(df):
    '''Drop rows with null values and none for game type and name'''
    #remove rows where type col is blank
    df = df[df['type'].notnull()]
    #remove rows where name is not defined
    df = df[df['name'].notnull()]
    df = df[df['name'] != 'none']
    #remove type col
    df = df.drop('type', axis=1)
    
    return df

def process(df):
    '''Process the dataframe to clean and use functions we create'''
    
    #copy df to avoid unhappy accidents
    df = df.copy()
    
    #Remove duplicate rows
    df = df.drop_duplicates()
    
    #Remove col with more than 50% null val
    df = drop_null_cols(df)
    
    #Remove rows with with null vals for game and type then drop type col
    df = drop_name_type(df)
    
    return df

# %%
print(raw_steam.shape)
initial_df = process(raw_steam)
print(initial_df.shape)
initial_df.head()
# Out:
# (29235, 39)
# (29075, 28)
#                         name  steam_appid  required_age is_free  \
# 0             Counter-Strike           10           0.0   False
# 1      Team Fortress Classic           20           0.0   False
# 2              Day of Defeat           30           0.0   False
# 3         Deathmatch Classic           40           0.0   False
# 4  Half-Life: Opposing Force           50           0.0   False
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements            developers  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  ['Gearbox Software']
#
#   publishers                                     price_overview packages  \
# 0  ['Valve']  {'currency': 'GBP', 'initial': 719, 'final': 7...      [7]
# 1  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [29]
# 2  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [30]
# 3  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [31]
# 4  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [32]
#
#                                       package_groups  \
# 0  [{'name': 'default', 'title': 'Buy Counter-Str...
# 1  [{'name': 'default', 'title': 'Buy Team Fortre...
# 2  [{'name': 'default', 'title': 'Buy Day of Defe...
# 3  [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4  [{'name': 'default', 'title': 'Buy Half-Life: ...
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies  achievements  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
#
#                                     release_date  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                  content_descriptors
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                         {'ids': [], 'notes': None}
# 3                         {'ids': [], 'notes': None}
# 4                         {'ids': [], 'notes': None}

# %% [markdown]
# # Age
#
# The next column to look at is required_age.

# %%
null_df = initial_df.isnull().sum()
print('empty age requirements:', null_df['required_age'])
# Out:
# empty age requirements: 0

# %%
initial_df['required_age'].value_counts(dropna=False).sort_index()
# Out:
# 0.0       28431
# 1.0           1
# 3.0          10
# 4.0           2
# 5.0           1
# 6.0           1
# 7.0           8
# 10.0          3
# 11.0          4
# 12.0         72
# 13.0         21
# 14.0          4
# 15.0         39
# 16.0        141
# 17.0         47
# 18.0        288
# 20.0          1
# 1818.0        1
# Name: required_age, dtype: int64

# %% [markdown]
# The range of age is between 0 and 20 with one likely error of 1818.
#
# Video games are a largely self regulated industry. In the US, ESRB puts ratings on games for recommended ages. In the rest of the world, PEGI puts ratings on games. ESRB uses letters (E, E10+, T, M) and PEGI uses numbers for ages (3, 7, 12, 16, 18).
#
# Binning by ages seeems more appropriate here so we'll use PEGI system.
#
# https://www.esrb.org/
#
# https://pegi.info/

# %%
initial_df[initial_df['required_age'] == 1818]
# Out:
#                                name  steam_appid  required_age is_free  \
# 28848  Симулятор Сидения у Подъезда      1031920        1818.0   False
#
#                                     detailed_description  \
# 28848  <h2 class="bb_tag">Симулятор Сидения у Подъезд...
#
#                                           about_the_game short_description  \
# 28848  <h2 class="bb_tag">Симулятор Сидения у Подъезд...              Гыгы
#
#                                      supported_languages  \
# 28848  Russian<strong>*</strong><br><strong>*</strong...
#
#                                             header_image website  \
# 28848  https://steamcdn-a.akamaihd.net/steam/apps/103...     NaN
#
#                                          pc_requirements  \
# 28848  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                         mac_requirements  \
# 28848  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                       linux_requirements  \
# 28848  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                   developers             publishers  \
# 28848  ['Kavkaz Sila Games']  ['Kavkaz Sila Games']
#
#                                           price_overview  packages  \
# 28848  {'currency': 'GBP', 'initial': 79, 'final': 47...  [343286]
#
#                                           package_groups  \
# 28848  [{'name': 'default', 'title': 'Buy Симулятор С...
#
#                                              platforms  \
# 28848  {'windows': True, 'mac': False, 'linux': False}
#
#                                               categories  \
# 28848  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                             genres  \
# 28848  [{'id': '28', 'description': 'Simulation'}]
#
#                                              screenshots  \
# 28848  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                                   movies  \
# 28848  [{'id': 256749019, 'name': '2', 'thumbnail': '...
#
#                                             achievements  \
# 28848  {'total': 1, 'highlighted': [{'name': 'Kavkaz ...
#
#                                          release_date  \
# 28848  {'coming_soon': False, 'date': '25 Apr, 2019'}
#
#                                            support_info  \
# 28848  {'url': '', 'email': 'hikkasimulator@gmail.com'}
#
#                                               background  \
# 28848  https://steamcdn-a.akamaihd.net/steam/apps/103...
#
#                              content_descriptors
# 28848  {'ids': [5], 'notes': 'Мат, жизнь в СНГ'}

# %%
def pegi_age(df):
    '''Bin age requirments according to PEGI standards'''
    #PEGI Age Ratings 3, 7, 12, 16, 18
    
    bins = [-1, 0, 3, 7, 12, 16, 2000]
    labels = [0, 3, 7, 12, 16, 18]
    
    df['required_age'] = pd.cut(df['required_age'], bins = bins, labels =labels)
    
    return df

# %%
age_df = pegi_age(initial_df)

# %%
age_df['required_age'].value_counts().sort_index()
# Out:
# 0     28431
# 3        11
# 7        12
# 12       79
# 16      205
# 18      337
# Name: required_age, dtype: int64

# %% [markdown]
# ## Price (to be cont...)
#
# The next column is whether the game is free to play or not displayed in boolean. It makes sense to deal with this when we deal with the price overview in the future. But lets take a sneak peak.

# %%
age_df['is_free'].value_counts()
# Out:
# False    26309
# True      2766
# Name: is_free, dtype: int64

# %%
age_df['price_overview'].head()
# Out:
# 0    {'currency': 'GBP', 'initial': 719, 'final': 7...
# 1    {'currency': 'GBP', 'initial': 399, 'final': 3...
# 2    {'currency': 'GBP', 'initial': 399, 'final': 3...
# 3    {'currency': 'GBP', 'initial': 399, 'final': 3...
# 4    {'currency': 'GBP', 'initial': 399, 'final': 3...
# Name: price_overview, dtype: object

# %% [markdown]
# is_free column is next but it makes sense to treat this with the cost column so we'll skip ahead to platforms

# %% [markdown]
# ## Platforms Column

# %% [markdown]
# Platforms on steam is what kind of Operating System the game can be played (Windows, MAC OS, linux)

# %%
age_df['platforms'].head()
# Out:
# 0    {'windows': True, 'mac': True, 'linux': True}
# 1    {'windows': True, 'mac': True, 'linux': True}
# 2    {'windows': True, 'mac': True, 'linux': True}
# 3    {'windows': True, 'mac': True, 'linux': True}
# 4    {'windows': True, 'mac': True, 'linux': True}
# Name: platforms, dtype: object

# %% [markdown]
# This column has a dictionary structure with keys representing the operating system and values representing whether the game can be played on that os.

# %%
null_df['platforms']
# Out:
# 0

# %% [markdown]
# No null values to worry about in this column.

# %%
def clean_platforms(df):
    '''Split platforms column into seperate boolean columns for each platform'''
    #evaluate values in platforms column
    df = df.copy()
    
    def parse_platforms(x):
        
        d = literal_eval(x)
        
        return ';'.join(platform for platform in d.keys() if d[platform])
    
    df['platforms'] = df['platforms'].apply(parse_platforms)
    
    return df

# %%
platforms_df = clean_platforms(age_df)
platforms_df['platforms'].value_counts()
# Out:
# windows              19887
# windows;mac;linux     4851
# windows;mac           3687
# windows;linux          643
# mac                      5
# mac;linux                1
# linux                    1
# Name: platforms, dtype: int64

# %% [markdown]
# Majority of games are only availabe on windows. With only one game available exclusively on linux.

# %%
platforms_df.head()
# Out:
#                         name  steam_appid required_age is_free  \
# 0             Counter-Strike           10            0   False
# 1      Team Fortress Classic           20            0   False
# 2              Day of Defeat           30            0   False
# 3         Deathmatch Classic           40            0   False
# 4  Half-Life: Opposing Force           50            0   False
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# 4                    English, French, German, Korean
#
#                                         header_image  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                        website  \
# 0                          NaN
# 1                          NaN
# 2  http://www.dayofdefeat.com/
# 3                          NaN
# 4                          NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements            developers  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 1  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 2  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 3  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...             ['Valve']
# 4  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...  ['Gearbox Software']
#
#   publishers                                     price_overview packages  \
# 0  ['Valve']  {'currency': 'GBP', 'initial': 719, 'final': 7...      [7]
# 1  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [29]
# 2  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [30]
# 3  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [31]
# 4  ['Valve']  {'currency': 'GBP', 'initial': 399, 'final': 3...     [32]
#
#                                       package_groups          platforms  \
# 0  [{'name': 'default', 'title': 'Buy Counter-Str...  windows;mac;linux
# 1  [{'name': 'default', 'title': 'Buy Team Fortre...  windows;mac;linux
# 2  [{'name': 'default', 'title': 'Buy Day of Defe...  windows;mac;linux
# 3  [{'name': 'default', 'title': 'Buy Deathmatch ...  windows;mac;linux
# 4  [{'name': 'default', 'title': 'Buy Half-Life: ...  windows;mac;linux
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies  achievements  \
# 0  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 1  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 2  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 3  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
# 4  [{'id': 0, 'path_thumbnail': 'https://steamcdn...    NaN  {'total': 0}
#
#                                     release_date  \
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                           {'url': '', 'email': ''}
# 2                           {'url': '', 'email': ''}
# 3                           {'url': '', 'email': ''}
# 4  {'url': 'https://help.steampowered.com', 'emai...
#
#                                           background  \
# 0  https://steamcdn-a.akamaihd.net/steam/apps/10/...
# 1  https://steamcdn-a.akamaihd.net/steam/apps/20/...
# 2  https://steamcdn-a.akamaihd.net/steam/apps/30/...
# 3  https://steamcdn-a.akamaihd.net/steam/apps/40/...
# 4  https://steamcdn-a.akamaihd.net/steam/apps/50/...
#
#                                  content_descriptors
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1  {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                         {'ids': [], 'notes': None}
# 3                         {'ids': [], 'notes': None}
# 4                         {'ids': [], 'notes': None}

# %% [markdown]
# ## Price (For real this time)

# %%
null_df['price_overview']
# Out:
# 3559

# %% [markdown]
# Before writing this off as a loss, lets see what gaps we can fill with the is_free column

# %%
free_null_price_index = platforms_df[(platforms_df['is_free']) & (platforms_df['price_overview'].isnull())]

free_null_price_index.shape[0]
# Out:
# 2713

# %%
not_free_null_price = platforms_df[(platforms_df['is_free'] == False) & (platforms_df['price_overview'].isnull())]

not_free_null_price
# Out:
#                                     name  steam_appid required_age is_free  \
# 63               The Ship: Single Player         2420            0   False
# 75     RollerCoaster Tycoon® 3: Platinum         2700            0   False
# 220                            BioShock™         7670            0   False
# 234         Sam & Max 101: Culture Shock         8200            0   False
# 235     Sam & Max 102: Situation: Comedy         8210            0   False
# ...                                  ...          ...          ...     ...
# 28470               Saint Paul Pre-Alpha      1013680            0   False
# 28611                   Doodle Creatures      1020440            0   False
# 28713                         Full Pitch      1025330            0   False
# 28796                       Space Expand      1029120            0   False
# 28830        Polygon's Royale : Season 1      1031310            0   False
#
#                                     detailed_description  \
# 63     For PC gamers who enjoy multiplayer games with...
# 75     Rollercoaster Tycoon 3 Platinum combines the e...
# 220    <h1>Special Offer</h1><p>Buying BioShock™ also...
# 234    <strong>Sam &amp; Max: Episode 1 - Culture Sho...
# 235    <strong>Sam &amp; Max: Episode 2 - Situation: ...
# ...                                                  ...
# 28470  The Saint Paul Multiplayer game is in pre-Alph...
# 28611  Play God &amp; Create an Amazing Creature Univ...
# 28713  Full Pitch is a classic arcade-alike game with...
# 28796  Take control and expand your empire through di...
# 28830  <img src="https://steamcdn-a.akamaihd.net/stea...
#
#                                           about_the_game  \
# 63     For PC gamers who enjoy multiplayer games with...
# 75     Rollercoaster Tycoon 3 Platinum combines the e...
# 220    BioShock is a shooter unlike any you've ever p...
# 234    <strong>Sam &amp; Max: Episode 1 - Culture Sho...
# 235    <strong>Sam &amp; Max: Episode 2 - Situation: ...
# ...                                                  ...
# 28470  The Saint Paul Multiplayer game is in pre-Alph...
# 28611  Play God &amp; Create an Amazing Creature Univ...
# 28713  Full Pitch is a classic arcade-alike game with...
# 28796  Take control and expand your empire through di...
# 28830  <img src="https://steamcdn-a.akamaihd.net/stea...
#
#                                        short_description  \
# 63     The Ship is a murder mystery alternative to tr...
# 75     Rollercoaster Tycoon 3 Platinum combines the e...
# 220    BioShock is a shooter unlike any you've ever p...
# 234    Sam &amp; Max: Episode 1 - Culture Shock - The...
# 235    Sam &amp; Max: Episode 2 - Situation: Comedy -...
# ...                                                  ...
# 28470  Alpha multiplayer game focusing on the local c...
# 28611  Play God &amp; Create an Amazing Creature Univ...
# 28713  Avoid disaster. Pass check points. Believe in ...
# 28796  Take control and expand your empire through di...
# 28830  Polygon's Royal is the battleground survival g...
#
#                                      supported_languages  \
# 63     English, French, German, Italian, Spanish - Sp...
# 75     English, French, Italian, German, Spanish - Sp...
# 220    English<strong>*</strong>, French<strong>*</st...
# 234                     English, French, German, Italian
# 235                             English, German, Italian
# ...                                                  ...
# 28470  English<strong>*</strong>, Portuguese - Brazil...
# 28611  English<strong>*</strong>, French, Italian, Ge...
# 28713  English, French, Italian, German, Spanish - Sp...
# 28796                                            English
# 28830                                            English
#
#                                             header_image  \
# 63     https://steamcdn-a.akamaihd.net/steam/apps/242...
# 75     https://steamcdn-a.akamaihd.net/steam/apps/270...
# 220    https://steamcdn-a.akamaihd.net/steam/apps/767...
# 234    https://steamcdn-a.akamaihd.net/steam/apps/820...
# 235    https://steamcdn-a.akamaihd.net/steam/apps/821...
# ...                                                  ...
# 28470  https://steamcdn-a.akamaihd.net/steam/apps/101...
# 28611  https://steamcdn-a.akamaihd.net/steam/apps/102...
# 28713  https://steamcdn-a.akamaihd.net/steam/apps/102...
# 28796  https://steamcdn-a.akamaihd.net/steam/apps/102...
# 28830  https://steamcdn-a.akamaihd.net/steam/apps/103...
#
#                                                  website  \
# 63     http://www.blazinggriffin.com/games/the-ship-m...
# 75     http://www.atari.com/rollercoastertycoon/us/in...
# 220                          http://www.BioShockGame.com
# 234            http://store.steampowered.com/app/901660/
# 235            http://store.steampowered.com/app/901660/
# ...                                                  ...
# 28470                        http://saintpaulstudios.com
# 28611                               http://doodlegod.com
# 28713                                                NaN
# 28796                                                NaN
# 28830                     https://www.polygonsroyale.com
#
#                                          pc_requirements  \
# 63     {'minimum': '<strong>Minimum:</strong> 1.8 GHz...
# 75     {'minimum': '<strong>Minimum: </strong><br>\t\...
# 220    {'minimum': '<h2 class="bb_tag"><strong>Minimu...
# 234    {'minimum': 'Windows XP or Vista, 1.5GHz proce...
# 235    {'minimum': 'Windows XP or Vista, 1.5GHz proce...
# ...                                                  ...
# 28470  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28611  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28713  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28796  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28830  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                         mac_requirements  \
# 63                                                    []
# 75     {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 220        {'minimum': 'Please See BioShock Remastered'}
# 234                                                   []
# 235                                                   []
# ...                                                  ...
# 28470                                                 []
# 28611  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28713                                                 []
# 28796                                                 []
# 28830  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                       linux_requirements  \
# 63                                                    []
# 75                                                    []
# 220                                                   []
# 234                                                   []
# 235                                                   []
# ...                                                  ...
# 28470                                                 []
# 28611  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28713                                                 []
# 28796                                                 []
# 28830  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                           developers                publishers price_overview  \
# 63               ['Outerlight Ltd.']  ['Blazing Griffin Ltd.']            NaN
# 75       ['Frontier', 'Aspyr (Mac)']  ['Atari', 'Aspyr (Mac)']            NaN
# 220    ['2K Boston', '2K Australia']                    ['2K']            NaN
# 234               ['Telltale Games']        ['Telltale Games']            NaN
# 235               ['Telltale Games']        ['Telltale Games']            NaN
# ...                              ...                       ...            ...
# 28470    ['Cleyton Jonnas da Silva']    ['Saint Paul Studios']            NaN
# 28611               ['JoyBits Ltd.']          ['JoyBits Ltd.']            NaN
# 28713                     ['Casque']                ['Casque']            NaN
# 28796                  ['Fost Hope']             ['Fost Hope']            NaN
# 28830         ['FlyingCubicle', '-']                     ['-']            NaN
#
#             packages                                     package_groups  \
# 63           [56669]  [{'name': 'default', 'title': 'Buy The Ship: S...
# 75               NaN                                                 []
# 220    [451, 127633]  [{'name': 'default', 'title': 'Buy BioShock™',...
# 234       [357, 539]  [{'name': 'default', 'title': 'Buy Sam & Max 1...
# 235       [358, 539]  [{'name': 'default', 'title': 'Buy Sam & Max 1...
# ...              ...                                                ...
# 28470            NaN                                                 []
# 28611            NaN                                                 []
# 28713       [340637]                                                 []
# 28796            NaN                                                 []
# 28830            NaN                                                 []
#
#                platforms                                         categories  \
# 63               windows        [{'id': 2, 'description': 'Single-player'}]
# 75           windows;mac        [{'id': 2, 'description': 'Single-player'}]
# 220              windows  [{'id': 2, 'description': 'Single-player'}, {'...
# 234              windows        [{'id': 2, 'description': 'Single-player'}]
# 235              windows        [{'id': 2, 'description': 'Single-player'}]
# ...                  ...                                                ...
# 28470            windows  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 28611  windows;mac;linux  [{'id': 2, 'description': 'Single-player'}, {'...
# 28713            windows        [{'id': 2, 'description': 'Single-player'}]
# 28796            windows  [{'id': 2, 'description': 'Single-player'}, {'...
# 28830  windows;mac;linux  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                   genres  \
# 63     [{'id': '1', 'description': 'Action'}, {'id': ...
# 75     [{'id': '28', 'description': 'Simulation'}, {'...
# 220    [{'id': '1', 'description': 'Action'}, {'id': ...
# 234    [{'id': '1', 'description': 'Action'}, {'id': ...
# 235    [{'id': '1', 'description': 'Action'}, {'id': ...
# ...                                                  ...
# 28470  [{'id': '1', 'description': 'Action'}, {'id': ...
# 28611  [{'id': '25', 'description': 'Adventure'}, {'i...
# 28713  [{'id': '1', 'description': 'Action'}, {'id': ...
# 28796  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 28830  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                              screenshots  \
# 63     [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 75     [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 220    [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 234    [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 235    [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# ...                                                  ...
# 28470  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 28611  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 28713  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 28796  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
# 28830  [{'id': 0, 'path_thumbnail': 'https://steamcdn...
#
#                                                   movies  achievements  \
# 63     [{'id': 2035597, 'name': 'the Ship:  Intro', '...  {'total': 0}
# 75                                                   NaN  {'total': 0}
# 220                                                  NaN  {'total': 0}
# 234                                                  NaN  {'total': 0}
# 235                                                  NaN  {'total': 0}
# ...                                                  ...           ...
# 28470  [{'id': 256740249, 'name': 'Saint Paul Pré Alp...  {'total': 0}
# 28611  [{'id': 256743963, 'name': 'Doodle Creatures T...           NaN
# 28713  [{'id': 256742104, 'name': 'Full Pitch', 'thum...           NaN
# 28796  [{'id': 256742432, 'name': 'Space Expand', 'th...           NaN
# 28830  [{'id': 256744966, 'name': 'T2', 'thumbnail': ...  {'total': 0}
#
#                                          release_date  \
# 63     {'coming_soon': False, 'date': '20 Nov, 2006'}
# 75     {'coming_soon': False, 'date': '12 Mar, 2008'}
# 220    {'coming_soon': False, 'date': '21 Aug, 2007'}
# 234    {'coming_soon': False, 'date': '15 Jun, 2007'}
# 235    {'coming_soon': False, 'date': '15 Jun, 2007'}
# ...                                               ...
# 28470   {'coming_soon': False, 'date': '3 Feb, 2019'}
# 28611               {'coming_soon': True, 'date': ''}
# 28713  {'coming_soon': False, 'date': '15 Mar, 2019'}
# 28796  {'coming_soon': False, 'date': '22 Feb, 2019'}
# 28830   {'coming_soon': False, 'date': '8 Mar, 2019'}
#
#                                             support_info  \
# 63                              {'url': '', 'email': ''}
# 75     {'url': 'http://www.atari.com/support/atari', ...
# 220               {'url': 'support.2k.com', 'email': ''}
# 234                             {'url': '', 'email': ''}
# 235                             {'url': '', 'email': ''}
# ...                                                  ...
# 28470  {'url': '', 'email': 'cleyton@saintpaulstudios...
# 28611  {'url': 'http://doodlegod.com', 'email': 'supp...
# 28713      {'url': '', 'email': 'CasqueGames@Gmail.com'}
# 28796                           {'url': '', 'email': ''}
# 28830  {'url': 'https://www.polygonsroyale.com/suppor...
#
#                                               background  \
# 63     https://steamcdn-a.akamaihd.net/steam/apps/242...
# 75     https://steamcdn-a.akamaihd.net/steam/apps/270...
# 220    https://steamcdn-a.akamaihd.net/steam/apps/767...
# 234    https://steamcdn-a.akamaihd.net/steam/apps/820...
# 235    https://steamcdn-a.akamaihd.net/steam/apps/821...
# ...                                                  ...
# 28470  https://steamcdn-a.akamaihd.net/steam/apps/101...
# 28611  https://steamcdn-a.akamaihd.net/steam/apps/102...
# 28713  https://steamcdn-a.akamaihd.net/steam/apps/102...
# 28796  https://steamcdn-a.akamaihd.net/steam/apps/102...
# 28830  https://steamcdn-a.akamaihd.net/steam/apps/103...
#
#                                      content_descriptors
# 63                            {'ids': [], 'notes': None}
# 75                            {'ids': [], 'notes': None}
# 220                           {'ids': [], 'notes': None}
# 234                           {'ids': [], 'notes': None}
# 235                           {'ids': [], 'notes': None}
# ...                                                  ...
# 28470  {'ids': [2, 5], 'notes': 'This game contains g...
# 28611                         {'ids': [], 'notes': None}
# 28713                         {'ids': [], 'notes': None}
# 28796                         {'ids': [], 'notes': None}
# 28830  {'ids': [2, 5], 'notes': ' General Mature Cont...
#
# [846 rows x 28 columns]

# %% [markdown]
# 846 games in our dataframe do not have a price listed. This is odd so lets investigate a handful.

# %%
not_free_sample = not_free_null_price.sample(n=5, random_state=RANDOM_STATE)

# %% [markdown]
# https://store.steampowered.com/app

# %%
def print_steam_links(df):
    url= 'https://store.steampowered.com/app/'
    
    for i, row in df.iterrows():
        appid = row['steam_appid']
        name = row['name']
        
        print(name + ':', url + str(appid))

# %%
print_steam_links(not_free_sample)
# Out:
# Eagle Island: https://store.steampowered.com/app/681110
# Rain of Reflections: Chapter 1: https://store.steampowered.com/app/695050
# Holobunnies: The Bittersweet Adventure: https://store.steampowered.com/app/369840
# Norman's Great Illusion: https://store.steampowered.com/app/463510
# Viscera Cleanup Detail: Shadow Warrior: https://store.steampowered.com/app/255520

# %% [markdown]
# * Eagle Island is a demo page
#
# * Rain of Reflections was in development at time fo data collection
#
# * Holobunnies does not have a price listed as it is in active development
#
# * Norman's Great Illusion was in development at time of data collection
#
# * Viscera Cleanup Detail: Shadow Warrior Multiple editions available
#
# For various reasons, the games do not have a price. We'll push off treating these for now as there might be other reasons they get dropped.

# %%
platforms_df['price_overview'][5]
# Out:
# "{'currency': 'GBP', 'initial': 399, 'final': 399, 'discount_percent': 0, 'initial_formatted': '', 'final_formatted': '£3.99'}"

# %%
def clean_price(df):
    df = df.copy()
    
    def parse_price(x):
        if x is not np.nan:
            return literal_eval(x)
        else:
            return {'currency': 'GBP', 'initial': -1}
    #evaluate as dictionary and set to -1 if missing
    df['price_overview'] = df['price_overview'].applg(parse_price)
    
    # Create columns from currency and initial values
    df['currency'] = df['price_overview'].apply(lambda x: x['currency'])
    df['price']    = df['price_overview'].apply(lambda x: x['initial'])
